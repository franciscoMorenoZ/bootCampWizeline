# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
url='https://drive.google.com/file/d/1PCJ7ltluquoXKi6MYTPMfwZQNI_-MIFP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
#Use this dictionary to store your answers in the correct format in the cells below , do not modify the keys
answer_dict =  {"Q1" : None,
                "Q2" : None,
                "Q3" : None,
                "Q4" : None,
                "Q5" : None,
                "Q6" : None,
                "Q7" : None}

# %%
df.head(100)
# Out:
#                 Make                Model          Year  Engine Displacement  \
# 0         AM General    DJ Po Vehicle 2WD  (1984, 1988)                  2.5
# 1         AM General     FJ8c Post Office  (1984, 1988)                  4.2
# 2         AM General  Post Office DJ5 2WD  (1984, 1988)                  2.5
# 3         AM General  Post Office DJ8 2WD  (1984, 1988)                  4.2
# 4   ASC Incorporated                  GNX  (1984, 1988)                  3.8
# ..               ...                  ...           ...                  ...
# 95             Acura               Legend  (1984, 1988)                  2.7
# 96             Acura               Legend  (1984, 1988)                  2.7
# 97             Acura               Legend  (1984, 1988)                  2.7
# 98             Acura               Legend  (1984, 1988)                  2.7
# 99             Acura               Legend  (1984, 1988)                  2.7
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
##Q1. What is the average CO2 emmission per gram/mile of all Volkswagen cars?
##Format: A floating number

# %%
volkswagen_df = df[df.Make == "Volkswagen"].copy()

# %%
volkswagen_df.head()
# Out:
#              Make   Model  Year  Engine Displacement  Cylinders  \
# 34128  Volkswagen  Beetle  2012                  2.0        4.0
# 34129  Volkswagen  Beetle  2012                  2.5        5.0
# 34130  Volkswagen  Beetle  2012                  2.0        4.0
# 34131  Volkswagen  Beetle  2012                  2.5        5.0
# 34132  Volkswagen  Beetle  2013                  2.0        4.0
#
#          Transmission         Drivetrain    Vehicle Class Fuel Type  \
# 34128  Automatic (S6)  Front-Wheel Drive  Subcompact Cars   Premium
# 34129  Automatic (S6)  Front-Wheel Drive  Subcompact Cars   Regular
# 34130    Manual 6-spd  Front-Wheel Drive  Subcompact Cars   Premium
# 34131    Manual 5-spd  Front-Wheel Drive  Subcompact Cars   Regular
# 34132    Manual 6-spd  Front-Wheel Drive     Compact Cars    Diesel
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 34128          13.184400        22           30            25
# ...

# %%
media = volkswagen_df["CO2 Emission Grams/Mile"].mean()

# %%
print(media)
# Out:
# 392.7417210857633

# %%
answer_dict["Q1"] =  media

# %%
###Q2.Calculate the top 5 brands(Make) with the most unique models, 
###order your answer in descending order with respect to the number of unique models.

# %%
df3 = df.groupby(['Make']).agg({'Make':'count'}).rename(columns={'Make':'count'}).reset_index()
(df3.sort_values('count',ascending=False)).head(5).values.tolist()
# Out:
# [['Chevrolet', 3643],
#  ['Ford', 2946],
#  ['Dodge', 2360],
#  ['GMC', 2347],
#  ['Toyota', 1836]]

# %%
answer_dict["Q2"] =  (df3.sort_values('count',ascending=False)).head(5).values.tolist()
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Chevrolet', 3643],
#   ['Ford', 2946],
#   ['Dodge', 2360],
#   ['GMC', 2347],
#   ['Toyota', 1836]],
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %%
#"""Q3. What are all the different types of fuels in the dataset sorted alphabetically?
#Format: A list of strings sorted alphabetically.
#Example Answer: ['Regular', 'Premium']
df4 = df['Fuel Type'].unique()
df4
# Out:
# array(['Regular', 'Premium', 'Diesel', 'Premium and Electricity',
#        'Premium or E85', 'Premium Gas or Electricity', 'Gasoline or E85',
#        'Gasoline or natural gas', 'CNG', 'Regular Gas or Electricity',
#        'Midgrade', 'Regular Gas and Electricity', 'Gasoline or propane'],
#       dtype=object)

# %%
print(sorted(df4))
# Out:
# ['CNG', 'Diesel', 'Gasoline or E85', 'Gasoline or natural gas', 'Gasoline or propane', 'Midgrade', 'Premium', 'Premium Gas or Electricity', 'Premium and Electricity', 'Premium or E85', 'Regular', 'Regular Gas and Electricity', 'Regular Gas or Electricity']

# %%
answer_dict["Q3"] =  sorted(df4)

# %%
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Chevrolet', 3643],
#   ['Ford', 2946],
#   ['Dodge', 2360],
#   ['GMC', 2347],
#   ['Toyota', 1836]],
#  'Q3': ['CNG',
#   'Diesel',
#   'Gasoline or E85',
#   'Gasoline or natural gas',
#   'Gasoline or propane',
#   'Midgrade',
#   'Premium',
#   'Premium Gas or Electricity',
#   'Premium and Electricity',
#   'Premium or E85',
#   'Regular',
#   'Regular Gas and Electricity',
#   'Regular Gas or Electricity'],
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %%
#Q4. Show the 9 Toyota cars with the most extreme Fuel Barrels/Year in abosolute terms within all Toyota cars. 
#Show the car Model, Year and their Fuel Barrels/Year in standard deviation units(Z-score) sorted in descending 
#order by their Fuel Barrels/Year in absolute terms first and then by year in descending order 
#BUT without modifying the negative values (see example).

# %%
toyota_df = df[df.Make == "Toyota"].copy()
toyota_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1836 entries, 32281 to 34116
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     1836 non-null   object
#  1   Model                    1836 non-null   object
#  2   Year                     1836 non-null   int64
#  3   Engine Displacement      1836 non-null   float64
#  4   Cylinders                1836 non-null   float64
#  5   Transmission             1836 non-null   object
#  6   Drivetrain               1836 non-null   object
#  7   Vehicle Class            1836 non-null   object
#  8   Fuel Type                1836 non-null   object
#  9   Fuel Barrels/Year        1836 non-null   float64
#  10  City MPG                 1836 non-null   int64
#  11  Highway MPG              1836 non-null   int64
#  12  Combined MPG             1836 non-null   int64
#  13  CO2 Emission Grams/Mile  1836 non-null   float64
# ...

# %%
toyota_df_sub_set = toyota_df[['Model','Year','Fuel Barrels/Year']].copy()
toyota_df_sub_set
# Out:
#                  Model  Year  Fuel Barrels/Year
# 32281  1-Ton Truck 2WD  1985          15.695714
# 32282  1-Ton Truck 2WD  1985          15.695714
# 32283  1-Ton Truck 2WD  1986          15.695714
# 32284  1-Ton Truck 2WD  1986          14.330870
# 32285  1-Ton Truck 2WD  1987          15.695714
# ...                ...   ...                ...
# 34112            Yaris  2016           9.988182
# 34113            Yaris  2017          10.300313
# 34114            Yaris  2017           9.988182
# 34115         Yaris iA  2017           9.694412
# 34116         Yaris iA  2017           9.417429
#
# [1836 rows x 3 columns]

# %%
#data_z = (toyota_df['Fuel Barrels/Year']-toyota_df['Fuel Barrels/Year'].mean())/(toyota_df['Fuel Barrels/Year'].std())
#data_z = (toyota_df-toyota_df.mean())/(toyota_df.std())
toyota_df_sub_set['Zscore'] = stats.zscore(toyota_df_sub_set['Fuel Barrels/Year'])
toyota_df_sub_set_sorted = toyota_df_sub_set.sort_values(['Zscore','Year'],ascending=True)
answer4 = toyota_df_sub_set_sorted.head(9).set_index('Model')
print(answer4)
# Out:
#                       Year  Fuel Barrels/Year    Zscore
# Model
# Camry CNG             1999           0.080870 -3.933613
# Camry CNG             2000           0.084545 -3.932714
# Camry CNG             2001           0.084545 -3.932714
# Prius Plug-in Hybrid  2013           4.737144 -2.794050
# Prius Plug-in Hybrid  2014           4.737144 -2.794050
# Prius Plug-in Hybrid  2015           4.737144 -2.794050
# Prius Plug-in Hybrid  2012           4.744612 -2.792222
# Prius Eco             2016           5.885893 -2.512908
# Prius Eco             2017           5.885893 -2.512908

# %%
answer_dict["Q4"] =  answer4
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Chevrolet', 3643],
#   ['Ford', 2946],
#   ['Dodge', 2360],
#   ['GMC', 2347],
#   ['Toyota', 1836]],
#  'Q3': ['CNG',
#   'Diesel',
#   'Gasoline or E85',
#   'Gasoline or natural gas',
#   'Gasoline or propane',
#   'Midgrade',
#   'Premium',
#   'Premium Gas or Electricity',
#   'Premium and Electricity',
#   'Premium or E85',
#   'Regular',
#   'Regular Gas and Electricity',
#   'Regular Gas or Electricity'],
#  'Q4':                       Year  Fuel Barrels/Year    Zscore
#  Model
#  Camry CNG             1999           0.080870 -3.933613
#  Camry CNG             2000           0.084545 -3.932714
#  Camry CNG             2001           0.084545 -3.932714
#  Prius Plug-in Hybrid  2013           4.737144 -2.794050
#  Prius Plug-in Hybrid  2014           4.737144 -2.794050
#  Prius Plug-in Hybrid  2015           4.737144 -2.794050
#  Prius Plug-in Hybrid  2012           4.744612 -2.792222
# ...

# %%
#Q5. Calculate the changes in Combined MPG with their previous model of all Golf cars with Manual 
#5-spd transmission and Regular Fuel Type. Show the Year, the Combined MPG and the calculated difference of MPG 
#in a list sorted by Year in ascending order.

# %%
volkswagen_df2 = (df[(df['Make'] == "Volkswagen")  & (df['Model'] == "Golf") & (df['Transmission'] == "Manual 5-spd") &(df['Fuel Type'] == "Regular")   ].copy())
volkswagen_df2_filtered = volkswagen_df2[['Year','Combined MPG']].copy()
volkswagen_df2_filtered.set_index('Year')
# Out:
#       Combined MPG
# Year
# 1986            26
# 1987            26
# 1988            25
# 1989            25
# 1999            24
# 2000            24
# 2001            24
# 2002            24
# 2003            24
# 2004            24
# 2005            24
# 2006            24
# 2010            25
# 2011            26
# 2012            26
# 2013            26
# 2015            30
# 2016            30
# 2017            29

# %%
volkswagen_df2_filtered['Difference'] = volkswagen_df2_filtered['Combined MPG'].diff()
answer5 = volkswagen_df2_filtered.fillna(0.0).set_index('Year').head(19)
answer5
# Out:
#       Combined MPG  Difference
# Year
# 1986            26         0.0
# 1987            26         0.0
# 1988            25        -1.0
# 1989            25         0.0
# 1999            24        -1.0
# 2000            24         0.0
# 2001            24         0.0
# 2002            24         0.0
# 2003            24         0.0
# 2004            24         0.0
# 2005            24         0.0
# 2006            24         0.0
# 2010            25         1.0
# 2011            26         1.0
# 2012            26         0.0
# 2013            26         0.0
# 2015            30         4.0
# 2016            30         0.0
# 2017            29        -1.0

# %%
answer_dict["Q5"] =  answer5
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Chevrolet', 3643],
#   ['Ford', 2946],
#   ['Dodge', 2360],
#   ['GMC', 2347],
#   ['Toyota', 1836]],
#  'Q3': ['CNG',
#   'Diesel',
#   'Gasoline or E85',
#   'Gasoline or natural gas',
#   'Gasoline or propane',
#   'Midgrade',
#   'Premium',
#   'Premium Gas or Electricity',
#   'Premium and Electricity',
#   'Premium or E85',
#   'Regular',
#   'Regular Gas and Electricity',
#   'Regular Gas or Electricity'],
#  'Q4':                       Year  Fuel Barrels/Year    Zscore
#  Model
#  Camry CNG             1999           0.080870 -3.933613
#  Camry CNG             2000           0.084545 -3.932714
#  Camry CNG             2001           0.084545 -3.932714
#  Prius Plug-in Hybrid  2013           4.737144 -2.794050
#  Prius Plug-in Hybrid  2014           4.737144 -2.794050
#  Prius Plug-in Hybrid  2015           4.737144 -2.794050
#  Prius Plug-in Hybrid  2012           4.744612 -2.792222
# ...

# %%
#Q6. What are the top 5 lowest CO2 Emission Grams/Mile emmisions of cars for each of the following brands: 
#Toyota, Ford, Volkswagen, Nissan, Honda
Brands_df = (df[(df['Make']=='Toyota') | (df['Make']=='Ford') | (df['Make']=='Volkswagen') | (df['Make']=='Nissan') | (df['Make']=='Honda')]).sort_values('CO2 Emission Grams/Mile',ascending=True)[['Make','CO2 Emission Grams/Mile']]
answer6 = (Brands_df.groupby(by='Make').apply(lambda x:x.nsmallest(5,['CO2 Emission Grams/Mile']))).set_index('Make').copy()
answer6
# Out:
#             CO2 Emission Grams/Mile
# Make
# Ford                     112.000000
# Ford                     129.000000
# Ford                     129.000000
# Ford                     129.000000
# Ford                     129.000000
# Honda                    130.000000
# Honda                    167.679245
# Honda                    167.679245
# Honda                    167.679245
# Honda                    167.679245
# Nissan                   249.000000
# Nissan                   254.000000
# Nissan                   254.500000
# Nissan                   254.500000
# Nissan                   254.500000
# Toyota                   133.000000
# Toyota                   133.000000
# Toyota                   133.000000
# Toyota                   133.000000
# Toyota                   158.000000
# Volkswagen               200.000000
# Volkswagen               200.000000
# Volkswagen               200.000000
# Volkswagen               200.000000
# Volkswagen               261.025641

# %%
answer_dict["Q6"] =  answer6
answer_dict
# Out:
# {'Q1': None,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6':             CO2 Emission Grams/Mile
#  Make
#  Ford                     112.000000
#  Ford                     129.000000
#  Ford                     129.000000
#  Ford                     129.000000
#  Ford                     129.000000
#  Honda                    130.000000
#  Honda                    167.679245
#  Honda                    167.679245
#  Honda                    167.679245
#  Honda                    167.679245
#  Nissan                   249.000000
#  Nissan                   254.000000
#  Nissan                   254.500000
#  Nissan                   254.500000
#  Nissan                   254.500000
#  Toyota                   133.000000
#  Toyota                   133.000000
#  Toyota                   133.000000
#  Toyota                   133.000000
#  Toyota                   158.000000
#  Volkswagen               200.000000
#  Volkswagen               200.000000
# ...

# %%
#Q7. Form 7 groups of 5 years to calculated the median Combined MPG of each group. The first group is from 1984 to 1988, 
#the second from 1989 to 1993 and so on. The last group will have years not appearing in the dataset.
subset = df[['Year', 'Combined MPG']].sort_values(['Year'],ascending=True)
subset.set_index('Year')
subset['Year'] = subset['Year'].astype(float)
subset.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:545, in Categorical.astype(self, dtype, copy)
#     544 try:
# --> 545     new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     546     fill_value = self.categories._na_value
#
# ValueError: invalid literal for int() with base 10: '(1984, 1988)'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [72], in <cell line: 5>()
#       3 subset = df[['Year', 'Combined MPG']].sort_values(['Year'],ascending=True)
#       4 subset.set_index('Year')
# ----> 5 subset['Year'] = subset['Year'].astype(int)
#       6 subset.info()
#
# ...

# %%
bins = [0,1989,1994,1999,2004,2009,2014,2019]
names = ["(1984, 1988)", "(1989, 1993)", "(1994, 1998)", "(1999, 2003)", "(2004, 2008)", "(2009, 2013)","(2014, 2018)"]
subset['Year'] = pd.cut(subset['Year'], bins, labels = names)
df['Year']= df['Year'].replace(np.nan, 0, regex=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 4>()
#       1 bins = [0,1989,1994,1999,2004,2009,2014,2019]
#       2 names = ["(1984, 1988)", "(1989, 1993)", "(1994, 1998)", "(1999, 2003)", "(2004, 2008)", "(2009, 2013)","(2014, 2018)"]
# ----> 4 subset['Year'] = pd.cut(subset['Year'], bins, labels = names)
#       5 df['Year']= df['Year'].replace(np.nan, 0, regex=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py:292, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     289     if (np.diff(bins.astype("float64")) < 0).any():
#     290         raise ValueError("bins must increase monotonically.")
# --> 292 fac, bins = _bins_to_cuts(
#     293     x,
#     294     bins,
#     295     right=right,
#     296     labels=labels,
#     297     precision=precision,
# ...

# %%
subset['Mean']= subset.groupby(by='Year').apply(lambda x:x['Combined MPG'].mean()))

# %%
subset = df[['Year', 'Combined MPG']].sort_values(['Year'],ascending=True)
subset.set_index('Year')
subset['Year'] = subset['Year'].astype(float)
subset.info()
bins = [0,1989,1994,1999,2004,2009,2014,2019]
names = ["(1984, 1988)", "(1989, 1993)", "(1994, 1998)", "(1999, 2003)", "(2004, 2008)", "(2009, 2013)","(2014, 2018)"]
subset['Year'] = pd.cut(subset['Year'], bins, labels = names)
df['Year']= df['Year'].replace(np.nan, 0, regex=True)
